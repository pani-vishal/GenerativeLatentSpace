# %%
import sys

import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
import seaborn as sns
import copy

from pylab import rcParams
from scipy.interpolate import interp1d
rcParams['figure.figsize'] = 10, 10

from Models.RealNVP import *
from sklearn import datasets
from Geometry.curves import trainableCurve, BezierCurve
import time

# %%
# For reproducibility
seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %%
device = "cuda"

# %%
# Only run once, then load saved model
# flow = train(datasets, max_epochs=10000)

# %%
# Load flow
path_model = "TrainedModels/flow.pth"
flow = RealNVP(tfm_layers=6, latent_dim=2, device=device).to(device)
# path_model = "TrainedModels/flow_mix.pth"
# flow = RealNVP(tfm_layers=6, latent_dim=2, device=device, distribution="mixture", num_modes=2).to(device)
flow.load_state_dict(torch.load(path_model))
flow.eval()
# Out:
# RealNVP(
#   (block_scale): Sequential(
#     (0): Linear(in_features=2, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=2, bias=True)
#     (5): Tanh()
#   )
#   (block_trans): Sequential(
#     (0): Linear(in_features=2, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=2, bias=True)
#   )
#   (net_trans): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (5): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
#   (net_scale): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#     (2): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#     (3): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#     (4): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#     (5): Sequential(
#       (0): Linear(in_features=2, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#       (5): Tanh()
#     )
#   )
# )

# %%
fig = plt.figure()
fig.patch.set_facecolor('w')

noisy_moons = datasets.make_moons(n_samples=1000, noise=.05)[0].astype(np.float32)
z = flow.to_latent(torch.from_numpy(noisy_moons).to(device))[0].cpu().detach().numpy()

plt.subplot(221)
plt.scatter(z[:, 0], z[:, 1])
plt.title(r'$z = f(X)$')

z = np.random.multivariate_normal(np.zeros(2), np.eye(2), 1000)
plt.subplot(222)
plt.scatter(z[:, 0], z[:, 1])
plt.title(r'$z \sim p(z)$')

plt.subplot(223)
x = datasets.make_moons(n_samples=1000, noise=.05)[0].astype(np.float32)
plt.scatter(x[:, 0], x[:, 1], c='r')
plt.title(r'$X \sim p(X)$')

plt.subplot(224)
x = flow.sample(1000).detach().cpu().numpy()
plt.scatter(x[:, 0, 0], x[:, 0, 1], c='r')
plt.title(r'$X = g(z)$')
# Out:
# Text(0.5, 1.0, '$X = g(z)$')

# %% [markdown]
# ## Length Based Optimization

# %%
# Discretization of geodesic curve
N_t = 100
latent_dim = 2
# bc0 = torch.Tensor([-2, -2])
# bc1 = torch.Tensor([2, 2])

bc0 = torch.Tensor([-1.3695,  0.0235])
bc1 = torch.Tensor([-0.7177,  0.4285])

### Parameters for training (As used by Mike)
lr_init = 1e0
lr_gamma = 0.95
max_node_count = 20
max_hard_schedules = 5
hard_schedule_factor = 0.3
max_epochs = 1000
val_epoch = 10
verbose = 1
M_batch_size = N_t

# Have a validation set of points to use for validation. Let's use half of N while training.
t_val = torch.linspace(0, 1, N_t)

gamma = trainableCurve(bc0, bc1, max_nodes=max_node_count)
gamma.to(device)
# Out:
# trainableCurve(
#   (new_nodes): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (1): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (2): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (3): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (4): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (5): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (6): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (7): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (8): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (9): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (10): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (11): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (12): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (13): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (14): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (15): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (16): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (17): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (18): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#       (19): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#   )
# )

# %% [markdown]
# ### Training the Geodesic

# %%
def run_gamma_epoch(flow, gamma, optimizer, scheduler, t_val, device, M_batch_size=4, train=True):
    dt = (t_val[1] - t_val[0]).to(device)
    t = t_val.to(device)

    if train:
        gamma.train()

        # Slightly perturb all the t values, such that it isn't sampled at the same points every time.
        perturb = torch.normal(torch.zeros_like(t), 0.1*dt).to(device)
        t = torch.min(torch.max(t+perturb, 0*t), 0*t+1)
    else:
        gamma.eval()
        return flow.energy_in_image_space(gamma, t_val, False, length=True).item()

    length = 0
    gamma.zero_grad()
    # TODO: Increase batch_size
    for batch in range(0, t_val.shape[0], M_batch_size):
        with torch.set_grad_enabled(True):
            # Here loss is the length
            loss = flow.energy_in_image_space(gamma, t[batch:batch+M_batch_size], True)
            # TODO: Inefficient
            length += flow.energy_in_image_space(gamma, t[batch:batch+M_batch_size], True, length=True)
            loss.backward()

    if train:
        optimizer.step()
        scheduler.step()

    return length.item()

# %%
# Start with straight line
best_gamma = copy.deepcopy(gamma)

# Now we are measuring in image space
best_length = flow.energy_in_image_space(best_gamma, t_val, False, length=True)

# Let tolerance depend on the length of straight line.
length_tol = best_length / 100.

print(f"Straight curve length in image space: {best_length:.3f}")

optimizer = torch.optim.Adam(gamma.parameters(), lr=lr_init, weight_decay=1e-4)

# Multiplies the given lr with lambda every call to the scheduler
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lambda epoch: lr_gamma)

hard_schedules = 0
length_history = [best_length]
loss_history = []

tick = time.perf_counter()
tock = tick - 100
for epoch in range(max_epochs):
    if (epoch+1) % val_epoch:
        # Training: best_gamma unchanged
        run_gamma_epoch(flow, gamma, optimizer, scheduler, t_val, device, M_batch_size=M_batch_size, train=True)
    else:
        # Validation
        length = run_gamma_epoch(flow, gamma, optimizer, scheduler, t_val, device, M_batch_size=M_batch_size, train=False)
        length_history.append(length)
        loss_history.append(flow.energy_in_image_space(gamma, t_val, False, length=False).item())
        if verbose >= 1:
            print('-'*10)
            print(f"Learning rate: {optimizer.param_groups[0]['lr']:.5e}")
            print(f"Epoch[{epoch+1:04d}/{max_epochs}]: Length: {length:.3f}")

        length_improvement = best_length - length
        if length < best_length:
            # Store current best network for minimal length
            if verbose >= 1:
                print("Found better curve!")
            best_gamma = copy.deepcopy(gamma)
            best_length = length
            tock = time.perf_counter()

        if length_improvement < length_tol:
            # In case the loss increases, we first wanna rapidly decrease lr before we add nodes.
            # We restart from the best solution when adding nodes or decreasing LR
            if hard_schedules >= max_hard_schedules:
                ### New Node
                if best_gamma.nodecount >= max_node_count:
                    print("Node limit reached!")
                    break
                if verbose >= 1:
                    print("*** Adding node ***")
                best_gamma.add_node()

            ### Set gamma, and Reset best_gamma so it isn't trained
            gamma = best_gamma
            best_gamma = copy.deepcopy(best_gamma)

            # Re-initialize the optimizer to only the gamma parameters with gradients
            optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, gamma.parameters()), lr=lr_init, weight_decay=1e-4)
            scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lambda epoch: lr_gamma)

            if hard_schedules < max_hard_schedules:
                if verbose >= 1:
                    print("* Decreasing LR *")
                hard_schedules += 1
                optimizer.param_groups[0]['lr'] *= hard_schedule_factor ** hard_schedules
            else:
                # Reset hardSchedules when adding new node
                hard_schedules = 0

print(f"New curve length: {best_length:.3f}")
print(f"Time for convergence: {tock - tick:.3f} secs")
# Out:
# Straight curve length in image space: 0.851
# ----------
# Learning rate: 6.30249e-01
# Epoch[0010/1000]: Length: 2.389
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0020/1000]: Length: 0.806
# Found better curve!
# ----------
# Learning rate: 1.19164e-01
# Epoch[0030/1000]: Length: 0.813
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0040/1000]: Length: 0.803
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0050/1000]: Length: 0.806
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0060/1000]: Length: 0.805
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0070/1000]: Length: 0.804
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0080/1000]: Length: 4.731
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0090/1000]: Length: 1.903
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0100/1000]: Length: 0.807
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0110/1000]: Length: 0.804
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0120/1000]: Length: 0.806
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0130/1000]: Length: 0.804
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0140/1000]: Length: 9.013
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0150/1000]: Length: 1.953
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0160/1000]: Length: 0.808
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0170/1000]: Length: 0.802
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0180/1000]: Length: 0.800
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0190/1000]: Length: 0.800
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0200/1000]: Length: 6.263
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0210/1000]: Length: 1.922
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0220/1000]: Length: 0.801
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0230/1000]: Length: 0.799
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0240/1000]: Length: 0.799
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0250/1000]: Length: 0.799
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0260/1000]: Length: 4.176
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0270/1000]: Length: 2.449
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0280/1000]: Length: 0.804
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0290/1000]: Length: 0.800
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0300/1000]: Length: 0.799
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0310/1000]: Length: 0.799
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0320/1000]: Length: 6.160
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0330/1000]: Length: 2.197
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0340/1000]: Length: 0.803
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0350/1000]: Length: 0.797
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0360/1000]: Length: 0.797
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0370/1000]: Length: 0.797
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0380/1000]: Length: 6.949
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0390/1000]: Length: 1.622
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0400/1000]: Length: 0.811
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0410/1000]: Length: 0.797
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0420/1000]: Length: 0.796
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0430/1000]: Length: 0.796
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0440/1000]: Length: 10.144
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0450/1000]: Length: 2.328
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0460/1000]: Length: 0.822
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0470/1000]: Length: 0.798
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0480/1000]: Length: 0.795
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0490/1000]: Length: 0.795
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0500/1000]: Length: 17.399
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0510/1000]: Length: 2.454
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0520/1000]: Length: 0.823
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0530/1000]: Length: 0.797
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0540/1000]: Length: 0.794
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0550/1000]: Length: 0.794
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0560/1000]: Length: 17.375
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0570/1000]: Length: 1.596
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0580/1000]: Length: 0.828
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0590/1000]: Length: 0.797
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0600/1000]: Length: 0.794
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0610/1000]: Length: 0.794
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0620/1000]: Length: 7.818
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0630/1000]: Length: 8.874
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0640/1000]: Length: 0.884
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0650/1000]: Length: 0.796
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0660/1000]: Length: 0.794
# Found better curve!
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0670/1000]: Length: 0.794
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0680/1000]: Length: 13.774
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0690/1000]: Length: 3.763
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0700/1000]: Length: 0.817
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0710/1000]: Length: 0.798
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0720/1000]: Length: 0.794
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0730/1000]: Length: 0.794
# Found better curve!
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0740/1000]: Length: 17.936
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0750/1000]: Length: 4.476
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0760/1000]: Length: 1.108
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0770/1000]: Length: 0.796
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0780/1000]: Length: 0.794
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0790/1000]: Length: 0.794
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0800/1000]: Length: 14.481
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0810/1000]: Length: 6.635
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0820/1000]: Length: 0.842
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0830/1000]: Length: 0.797
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0840/1000]: Length: 0.794
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0850/1000]: Length: 0.794
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0860/1000]: Length: 22.985
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0870/1000]: Length: 3.240
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0880/1000]: Length: 0.825
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0890/1000]: Length: 0.796
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0900/1000]: Length: 0.794
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0910/1000]: Length: 0.794
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0920/1000]: Length: 24.254
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0930/1000]: Length: 13.151
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[0940/1000]: Length: 0.865
# * Decreasing LR *
# ----------
# Learning rate: 1.70167e-02
# Epoch[0950/1000]: Length: 0.801
# * Decreasing LR *
# ----------
# Learning rate: 5.10502e-03
# Epoch[0960/1000]: Length: 0.794
# * Decreasing LR *
# ----------
# Learning rate: 1.53151e-03
# Epoch[0970/1000]: Length: 0.794
# *** Adding node ***
# ----------
# Learning rate: 6.30249e-01
# Epoch[0980/1000]: Length: 15.766
# * Decreasing LR *
# ----------
# Learning rate: 1.89075e-01
# Epoch[0990/1000]: Length: 12.265
# * Decreasing LR *
# ----------
# Learning rate: 5.67224e-02
# Epoch[1000/1000]: Length: 0.867
# * Decreasing LR *
# New curve length: 0.794
# Time for convergence: 18.621 secs

# %% [markdown]
# ## Scratch

# %%
t_val = torch.linspace(0, 1, 20)
curve_pts = gamma(t_val)[0]
image_pts, log_det_j = flow.to_image(curve_pts[:, None, :])

# %%
fig = plt.figure()
fig.patch.set_facecolor('w')

z = np.random.multivariate_normal(np.zeros(2), np.eye(2), 1000)
plt.subplot(211)
plt.scatter(z[:, 0], z[:, 1])
plt.plot(curve_pts[:, 0].cpu().detach().numpy(), curve_pts[:, 1].cpu().detach().numpy(), c='g')

plt.title(r'$z \sim p(z)$')

plt.subplot(212)
x = flow.sample(1000).detach().cpu().numpy()
plt.scatter(x[:, 0, 0], x[:, 0, 1], c='r')
plt.plot(image_pts[:, 0, 0].cpu().detach().numpy(), image_pts[:, 0, 1].cpu().detach().numpy(), c='g')
plt.title(r'$X = g(z)$')
# Out:
# Text(0.5, 1.0, '$X = g(z)$')

# %%
curve_pts = best_gamma(t_val)[0]
image_pts, log_det_j = flow.to_image(curve_pts[:, None, :])
image_pts = torch.squeeze(image_pts, axis=1)
image_gds = tensor_linspace(image_pts[0, :], image_pts[-1, :], image_pts.shape[0])

# %%
latent_gds, _ = flow.to_latent(image_gds)
latent_gds.shape
# Out:
# torch.Size([20, 2])

# %%
fig = plt.figure()
fig.patch.set_facecolor('w')

plt.subplot(211)
plt.scatter(z[:, 0], z[:, 1])
plt.plot(curve_pts[:, 0].cpu().detach().numpy(), curve_pts[:, 1].cpu().detach().numpy(), c='g')
plt.plot(latent_gds[:, 0].cpu().detach().numpy(), latent_gds[:, 1].cpu().detach().numpy(), c='y')

plt.title(r'$z \sim p(z)$')

plt.subplot(212)
plt.scatter(x[:, 0, 0], x[:, 0, 1], c='r')
plt.plot(image_pts[:, 0].cpu().detach().numpy(), image_pts[:, 1].cpu().detach().numpy(), c='g')
plt.plot(image_gds[:, 0].cpu().detach().numpy(), image_gds[:, 1].cpu().detach().numpy(), c='y')
plt.title(r'$X = g(z)$')
# Out:
# Text(0.5, 1.0, '$X = g(z)$')

# %% [markdown]
# ## Loss history

# %%
loss_history = np.array(loss_history)
fig = plt.figure()
fig.patch.set_facecolor('w')
plt.plot(loss_history)
plt.title(f"Loss - Length-Based (Min: {loss_history.min():.5f}, Max: {loss_history.max():.5f})")
plt.grid()
plt.savefig("Outputs/loss_len.png")

# %%
length_history = np.array(length_history)
fig = plt.figure()
fig.patch.set_facecolor('w')
plt.plot(length_history)
plt.title(f"Length - Length-Based (Min: {length_history.min():.5f}, Max: {length_history.max():.5f})")
plt.grid()
plt.legend
plt.savefig("Outputs/len_len.png")
